# %% [markdown]
# # Left Join without Intersection

# %%
import pandas as pd

# %%
men2004 = pd.read_csv("../Course_Materials_Part2/Video_Lecture_NBs/men2004.csv")
men2008 = pd.read_csv("../Course_Materials_Part2/Video_Lecture_NBs/men2008.csv")

# %%
men2004.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
men2008.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
men2004.merge(men2008, how="outer", suffixes=("_2004", "_2008"), indicator=True)
# Out:
#               Athlete  Medals      _merge
# 0     PHELPS, Michael       8        both
# 1         THORPE, Ian       4   left_only
# 2    SCHOEMAN, Roland       3   left_only
# 3      PEIRSOL, Aaron       3        both
# 4        CROCKER, Ian       3   left_only
# ..                ...     ...         ...
# 109  LAGUNOV, Evgeniy       1  right_only
# 110     BERENS, Ricky       1  right_only
# 111      LURZ, Thomas       1  right_only
# 112   MALLET, Gregory       1  right_only
# 113        ZHANG, Lin       1  right_only
#
# [114 rows x 3 columns]

# %%
men0408 = men2004.merge(men2008, how="outer", on="Athlete", suffixes=("_2004", "_2008"), indicator=True)

# %%
mask = men0408._merge ==  "left_only"

# %%
men0408[mask]
# Out:
#                        Athlete  Medals_2004  Medals_2008     _merge
# 1                  THORPE, Ian          4.0          NaN  left_only
# 2             SCHOEMAN, Roland          3.0          NaN  left_only
# 7   VAN DEN HOOGENBAND, Pieter          3.0          NaN  left_only
# 9               MORITA, Tomomi          2.0          NaN  left_only
# 11               ROGAN, Markus          2.0          NaN  left_only
# 13              HALL, Gary Jr.          2.0          NaN  left_only
# 15                WALKER, Neil          2.0          NaN  left_only
# 16           YAMAMOTO, Takashi          2.0          NaN  left_only
# 17          SPRENGER, Nicholas          1.0          NaN  left_only
# 18          OKUMURA, Yoshihiro          1.0          NaN  left_only
# 19              PARRY, Stephen          1.0          NaN  left_only
# 20               PEARSON, Todd          1.0          NaN  left_only
# 21              ZASTROW, Mitja          1.0          NaN  left_only
# ...

# %%
men0408[mask].shape
# Out:
# (43, 4)
