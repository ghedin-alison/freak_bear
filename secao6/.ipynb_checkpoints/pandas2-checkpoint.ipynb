# %% [markdown]
# # How you should not do it

# %% [markdown]
# ### Import de bibliotecas

# %%
import pandas as pd

# %%
titanic = pd.read_csv('../Course_Materials_Part1/Video_Lecture_NBs/titanic.csv')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
age = titanic.age

# %%
age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
age[1] = 40
# Out:
# <ipython-input-6-1766d57c0659>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age[1] = 40

# %%
age.head()
# Out:
# 0    22.0
# 1    40.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  40.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.age[1] = 41 #this is chained indexing!!
# Out:
# <ipython-input-9-0bad6ae0d058>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic.age[1] = 41 #this is chained indexing!!

# %%
titanic.loc[1, "age"] = 42 # this is Not Chained indexing and the best way do do it!!

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  42.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
slice1 = titanic[["sex", "age"]]

# %%
slice1.head()
# Out:
#       sex   age
# 0    male  22.0
# 1  female  42.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0

# %%
slice1.iloc[1,1] = 43
# Out:
# /home/alison/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
slice1
# Out:
#         sex   age
# 0      male  22.0
# 1    female  43.0
# 2    female  26.0
# 3    female  35.0
# 4      male  35.0
# ..      ...   ...
# 886    male  27.0
# 887  female  19.0
# 888  female   NaN
# 889    male  26.0
# 890    male  32.0
#
# [891 rows x 2 columns]

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  42.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
slice2 = titanic.loc[:, ["sex", "age"]]
slice2
# Out:
#         sex   age
# 0      male  22.0
# 1    female  42.0
# 2    female  26.0
# 3    female  35.0
# 4      male  35.0
# ..      ...   ...
# 886    male  27.0
# 887  female  19.0
# 888  female   NaN
# 889    male  26.0
# 890    male  32.0
#
# [891 rows x 2 columns]

# %%
slice2.iloc[1,1] = 44

# %%
slice2.head()
# Out:
#       sex   age
# 0    male  22.0
# 1  female  44.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0

# %%
titanic.head() # it doesn work to main df
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  42.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
index_babies = titanic[titanic.age < 1].index

# %%
index_babies
# Out:
# Int64Index([78, 305, 469, 644, 755, 803, 831], dtype='int64')

# %%
titanic[titanic.age < 1][["age"]] = 1
# Out:
# <ipython-input-27-d8952b0d2b78>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic[titanic.age < 1][["age"]] = 1
# /home/alison/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
titanic.loc[index_babies, :]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 78          1       2    male  0.83      0      2   29.0000        S  NaN
# 305         1       1    male  0.92      1      2  151.5500        S    C
# 469         1       3  female  0.75      2      1   19.2583        C  NaN
# 644         1       3  female  0.75      2      1   19.2583        C  NaN
# 755         1       2    male  0.67      1      1   14.5000        S  NaN
# 803         1       3    male  0.42      0      1    8.5167        C  NaN
# 831         1       2    male  0.83      1      1   18.7500        S  NaN

# %%
titanic["age"][titanic.age < 1] = 1
# Out:
# <ipython-input-29-38060aef4190>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic["age"][titanic.age < 1] = 1

# %%
titanic.loc[index_babies]
# Out:
#      survived  pclass     sex  age  sibsp  parch      fare embarked deck
# 78          1       2    male  1.0      0      2   29.0000        S  NaN
# 305         1       1    male  1.0      1      2  151.5500        S    C
# 469         1       3  female  1.0      2      1   19.2583        C  NaN
# 644         1       3  female  1.0      2      1   19.2583        C  NaN
# 755         1       2    male  1.0      1      1   14.5000        S  NaN
# 803         1       3    male  1.0      0      1    8.5167        C  NaN
# 831         1       2    male  1.0      1      1   18.7500        S  NaN

# %%
titanic[["sex", "age"]][titanic.age == 1]["age"] = 0

# %%
titanic.loc[index_babies]
# Out:
#      survived  pclass     sex  age  sibsp  parch      fare embarked deck
# 78          1       2    male  1.0      0      2   29.0000        S  NaN
# 305         1       1    male  1.0      1      2  151.5500        S    C
# 469         1       3  female  1.0      2      1   19.2583        C  NaN
# 644         1       3  female  1.0      2      1   19.2583        C  NaN
# 755         1       2    male  1.0      1      1   14.5000        S  NaN
# 803         1       3    male  1.0      0      1    8.5167        C  NaN
# 831         1       2    male  1.0      1      1   18.7500        S  NaN

# %% [markdown]
# ## SettingWithCopyWarning: you assigned new values with chained indexing. It is not clear, whether you changed the original DF and whether this was your intention at all. So, please, CHECK!!!!
